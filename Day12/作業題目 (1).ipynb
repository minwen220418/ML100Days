# %% [markdown]
# 作業目標:<br>
# 1. 靈活運用圖表在各種情況下
# 2. 圖表的解讀

# %% [markdown]
# 作業重點:<br>
# 1. 依據需求畫出圖表<br>
# 2. 在做圖表解釋時，須了解圖表中的含意

# %% [markdown]
# 題目 : 將資料夾中boston.csv讀進來，並用圖表分析欄位。<br>
# 1.畫出箱型圖，並判斷哪個欄位的中位數在300~400之間?<br>
# 2.畫出散佈圖 x='NOX', y='DIS' ，並說明這兩欄位有什麼關係?

# %%
import pandas as pd
import numpy as np

# %%
boston = pd.read_csv("C:\\Users\\112178\\Desktop\\cupoy\\boston (1).csv")
boston
# Out:
#      key     CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0      1  0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 1      2  0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 2      3  0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 3      4  0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# 4      5  0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# ..   ...      ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 500  501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 501  502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 502  503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 503  504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 504  505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       17.8  396.90   9.14
# 1       17.8  392.83   4.03
# 2       18.7  394.63   2.94
# 3       18.7  396.90   5.33
# 4       18.7  394.12   5.21
# ..       ...     ...    ...
# 500     21.0  391.99   9.67
# 501     21.0  396.90   9.08
# 502     21.0  396.90   5.64
# 503     21.0  393.45   6.48
# 504     21.0  396.90   7.88
#
# [505 rows x 14 columns]

# %%
#1.畫出箱型圖，並判斷哪個欄位的中位數在300~400之間?
#TAX 和 B 的中位數在300~400之間
boston.boxplot()

# %%
#2. 畫出散佈圖 x='NOX', y='DIS' ，並說明這兩欄位有什麼關係?
#NOX 和 DIS 負相關 相關係數為-0.7692
boston.plot.scatter(x='NOX', y='DIS')
boston.corr()
# Out:
#               key      CRIM        ZN     INDUS      CHAS       NOX        RM  \
# key      1.000000  0.407248 -0.102731  0.396857 -0.004707  0.399434 -0.078802
# CRIM     0.407248  1.000000 -0.200283  0.406251 -0.056132  0.420934 -0.218978
# ZN      -0.102731 -0.200283  1.000000 -0.534022 -0.042550 -0.516574  0.311835
# INDUS    0.396857  0.406251 -0.534022  1.000000  0.062350  0.764556 -0.391330
# CHAS    -0.004707 -0.056132 -0.042550  0.062350  1.000000  0.091134  0.091497
# NOX      0.399434  0.420934 -0.516574  0.764556  0.091134  1.000000 -0.302127
# RM      -0.078802 -0.218978  0.311835 -0.391330  0.091497 -0.302127  1.000000
# AGE      0.203980  0.352701 -0.569524  0.645543  0.086461  0.731461 -0.240211
# DIS     -0.302634 -0.379627  0.664395 -0.708848 -0.099109 -0.769221  0.205170
# RAD      0.685322  0.625396 -0.311717  0.594167 -0.007907  0.611758 -0.209277
# TAX      0.666612  0.582568 -0.314351  0.720561 -0.035965  0.668141 -0.291680
# PTRATIO  0.287537  0.289394 -0.391713  0.380955 -0.122570  0.188918 -0.355116
# B       -0.294461 -0.384839  0.175319 -0.356506  0.049040 -0.380006  0.127754
# LSTAT    0.255833  0.455329 -0.412894  0.602737 -0.054576  0.591262 -0.613734
#
#               AGE       DIS       RAD       TAX   PTRATIO         B     LSTAT
# key      0.203980 -0.302634  0.685322  0.666612  0.287537 -0.294461  0.255833
# CRIM     0.352701 -0.379627  0.625396  0.582568  0.289394 -0.384839  0.455329
# ZN      -0.569524  0.664395 -0.311717 -0.314351 -0.391713  0.175319 -0.412894
# INDUS    0.645543 -0.708848  0.594167  0.720561  0.380955 -0.356506  0.602737
# CHAS     0.086461 -0.099109 -0.007907 -0.035965 -0.122570  0.049040 -0.054576
# NOX      0.731461 -0.769221  0.611758  0.668141  0.188918 -0.380006  0.591262
# RM      -0.240211  0.205170 -0.209277 -0.291680 -0.355116  0.127754 -0.613734
# AGE      1.000000 -0.747872  0.456232  0.506527  0.261724 -0.273486  0.602782
# DIS     -0.747872  1.000000 -0.494798 -0.534492 -0.232561  0.291451 -0.497277
# RAD      0.456232 -0.494798  1.000000  0.910202  0.463322 -0.444065  0.487608
# TAX      0.506527 -0.534492  0.910202  1.000000  0.460100 -0.441505  0.543435
# PTRATIO  0.261724 -0.232561  0.463322  0.460100  1.000000 -0.176515  0.372148
# B       -0.273486  0.291451 -0.444065 -0.441505 -0.176515  1.000000 -0.365637
# LSTAT    0.602782 -0.497277  0.487608  0.543435  0.372148 -0.365637  1.000000
